# %%
import pickle

# %%
filename = 'RFR.sav'

loaded_model = pickle.load(open(filename, 'rb'))
# result = loaded_model.score(X_test, Y_test)
# print(result)

# %%
x_test = pickle.load(open("test", 'rb'))

# %%
y_hat = loaded_model.predict(x_test)

# %%
y_hat
# Out:
# array([3.37577885, 4.51921595, 3.72413845, 4.10219127, 3.49226492,
#        3.97455168, 3.95749696, 3.56467606, 4.09851824, 3.74553672,
#        3.88395866, 4.09469923, 3.10016963, 3.77570128, 3.01752922,
#        4.16645081, 4.5546217 , 3.8209624 , 4.06135059, 3.80101571,
#        4.10943101, 4.30180482, 3.70778565, 3.31267309, 3.74966569,
#        3.78217226, 4.09147436, 3.81194085, 3.90749844, 3.04839254,
#        3.89496694, 3.67966921, 4.23422148, 3.66252223, 3.87291777,
#        3.24569503, 4.32376662, 3.98403145, 3.59120007, 3.32396917,
#        3.7699458 , 3.98290641, 3.55789592, 3.83129659, 4.09102864,
#        3.57770071, 4.26795705, 4.18220958, 3.60541493, 3.94774413,
#        3.67058244, 4.47185354, 3.3969197 , 3.65389695, 3.87898834,
#        3.65829646, 4.23553907, 3.57785852, 3.958617  , 4.06905651,
#        3.86158044, 4.07294711, 3.60462906, 4.23182665, 3.98676127,
#        3.2412389 , 3.02080192, 4.09982091, 3.14572943, 4.22437602,
# ...
