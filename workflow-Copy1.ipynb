# %% [markdown]
# # Machine Learning - Final project
# ### Empathy Prediction using the [Young people survey](https://www.kaggle.com/miroslavsabo/young-people-survey/) dataset

# %% [markdown]
# #### Loading datasets

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from numpy import *

sns.set(style="white", color_codes=True)
sns.set_context(rc={"font.family":'sans',"font.size":16,"axes.titlesize":16,"axes.labelsize":16})  
pd.options.display.max_columns = 150
pd.options.display.max_rows = 150

# %%
df = pd.read_csv('./input/responses.csv')
columns_desc = pd.read_csv('./input/columns.csv')

# %%
df.shape
# Out:
# (1010, 150)

# %% [markdown]
# #### Defining way to access description easily

# %%
all_columns =list(df)

desc = {}
for col_name in all_columns:
    desc[col_name] = columns_desc.loc[columns_desc['short'] == col_name].iloc[0][0]
    
def print_desc(column_name):
    print(column_name+" --> "+desc[column_name])

# %% [markdown]
# Example:

# %%
for col in all_columns[:5]:
    print_desc(col)
# Out:
# Music --> I enjoy listening to music.
# Slow songs or fast songs --> I prefer.
# Dance --> Dance, Disco, Funk
# Folk --> Folk music
# Country --> Country

# %% [markdown]
# # Data Exploration and preprocessing
#
# We can start by looking at some statistics of the features, from where we can notice given the average Empathy of 3.858706 and its standard deviation, which is not that high, that most of the people are actually very Empathetic.

# %%
df.describe()
# Out:
#              Music  Slow songs or fast songs        Dance         Folk  \
# count  1007.000000               1008.000000  1006.000000  1005.000000
# mean      4.731877                  3.328373     3.113320     2.288557
# std       0.664049                  0.833931     1.170568     1.138916
# min       1.000000                  1.000000     1.000000     1.000000
# 25%       5.000000                  3.000000     2.000000     1.000000
# 50%       5.000000                  3.000000     3.000000     2.000000
# 75%       5.000000                  4.000000     4.000000     3.000000
# max       5.000000                  5.000000     5.000000     5.000000
#
#            Country  Classical music      Musical          Pop         Rock  \
# count  1005.000000      1003.000000  1008.000000  1007.000000  1004.000000
# mean      2.123383         2.956132     2.761905     3.471698     3.761952
# std       1.076136         1.252570     1.260845     1.161400     1.184861
# min       1.000000         1.000000     1.000000     1.000000     1.000000
# 25%       1.000000         2.000000     2.000000     3.000000     3.000000
# 50%       2.000000         3.000000     3.000000     4.000000     4.000000
# 75%       3.000000         4.000000     4.000000     4.000000     5.000000
# max       5.000000         5.000000     5.000000     5.000000     5.000000
#
#        Metal or Hardrock         Punk  Hiphop, Rap  Reggae, Ska  Swing, Jazz  \
# count        1007.000000  1002.000000  1006.000000  1003.000000  1004.000000
# mean            2.361470     2.456088     2.910537     2.769691     2.759960
# std             1.372995     1.301105     1.375677     1.214434     1.257936
# min             1.000000     1.000000     1.000000     1.000000     1.000000
# 25%             1.000000     1.000000     2.000000     2.000000     2.000000
# 50%             2.000000     2.000000     3.000000     3.000000     3.000000
# 75%             3.000000     3.000000     4.000000     4.000000     4.000000
# max             5.000000     5.000000     5.000000     5.000000     5.000000
#
#        
# 50%            3.000000          3.000000                3.000000
# 75%            4.000000          4.000000                4.000000
# max            5.000000          5.000000                5.000000
#
#        Spending on looks  Spending on gadgets  Spending on healthy eating  \
# count        1007.000000          1010.000000                  1008.00000
# mean            3.106256             2.870297                     3.55754
# std             1.205368             1.284970                     1.09375
# min             1.000000             1.000000                     1.00000
# 25%             2.000000             2.000000                     3.00000
# 50%             3.000000             3.000000                     4.00000
# 75%             4.000000             4.000000                     4.00000
# max             5.000000             5.000000                     5.00000
#
#                Age      Height      Weight  Number of siblings
# count  1003.000000  990.000000  990.000000         1004.000000
# mean     20.433699  173.514141   66.405051            1.297809
# std       2.828840   10.024505   13.839561            1.013348
# min      15.000000   62.000000   41.000000            0.000000
# 25%      19.000000  167.000000   55.000000            1.000000
# 50%      20.000000  173.000000   64.000000            1.000000
# 75%      22.000000  180.000000   75.000000            2.000000
# max      30.000000  203.000000  165.000000           10.000000

# %% [markdown]
# Since we are dealing with people data, I think it would be interesting to see what kind of people we have and if they can somewhat be clustered in different groups. One of the features that could better describe different type of people could be the age

# %%
sns.set(style="darkgrid", color_codes=True)

fig, ax = plt.subplots(nrows=2, sharex=True, figsize=(8, 4))
col = 'Age'

_ = sns.distplot(
    df[col].dropna(),
    bins=np.arange(df[col].min() - 0.5, df[col].max() + 0.5, 1),
    ax=ax[0])
_ = sns.boxplot(df[col].dropna())
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# The average is around 20 and the standard deviation seems pretty low, the age has a normal distribution, this makes me think that the age will not have much importance as a feature. There are a few outliers that I would have eliminated if we had had a very big dataset, it is not worth it to eliminate them in this case

# %%
df.rename(columns={'Left - right handed': 'LeftRightHanded', 'Village - town': 'VillageTown', 'Internet usage': 'InternetUsage', 'Only child': 'OnlyChild', 'House - block of flats': 'HouseFlats'}, inplace=True)

# %%
all_columns =list(df)

# %% [markdown]
# ## Missing values handling

# %% [markdown]
# Let's start by looking at how many rows are missing a class label, I will delete these rows since it makes no sense to impute them, train or test using them

# %%
df['Empathy'].isna().sum()
# Out:
# 5

# %%
df.dropna(subset=['Empathy'], inplace=True)

# %%
df.shape
# Out:
# (1005, 150)

# %% [markdown]
# Let's now look at the percentage of missing values in all columns in desc order

# %%
df_na = (df.isnull().sum() / len(df)) * 100
df_na = df_na.drop(df_na[df_na == 0].index).sort_values(ascending=False)
missing_data = pd.DataFrame({'Missing Ratio': df_na})
missing_data.head(150).T
# Out:
#                 Height   Weight  Passive sport  Chemistry  Geography  Theatre  \
# Missing Ratio  1.99005  1.99005       1.492537   0.995025   0.895522  0.79602
#
#                Documentary  Smoking   Latino     Punk  Criminal damage  \
# Missing Ratio      0.79602  0.79602  0.79602  0.79602         0.696517
#
#                Compassion to animals  Final judgement  Reggae, Ska  Gardening  \
# Missing Ratio               0.696517         0.696517     0.696517   0.696517
#
#                Alternative  Rock n roll  Techno, Trance       Age  \
# Missing Ratio     0.696517     0.696517        0.696517  0.696517
#
#                Classical music  Swing, Jazz    Movies   Biology   Reading  \
# Missing Ratio         0.696517     0.597015  0.597015  0.597015  0.597015
#
#                  Giving        PC    Gender  Number of siblings  \
# Missing Ratio  0.597015  0.597015  0.597015            0.597015
#
#                Responding to a serious letter  Daily events  \
# Missing Ratio                        0.597015      0.597015
#
#                Science and technology  Art exhibitions  Friends versus money  \
# Missing Ratio                0.597015         0.597015              0.597015
#
#                 Writing  Countryside, outdoors      Rock      Folk  \
# Missing Ratio  0.597015               0.597015  0.597015  0.497512
#
#                Self-criticism   Spiders   Country  Economy Management  \
# Missing Ratio        0.497512  0.497512  0.497512            0.497512
#
#                Energy levels  Workaholism  Psychology  Foreign languages  \
# Missing Ratio       0.497512     0.497512    0.497512           0.497512
#
#                Prioritising workload  Getting up  Medicine   Alcohol  \
# Missing Ratio               0.497512    0.497512  0.497512  0.497512
#
#                Socializing  VillageTown     Pets  Active sport  Reliability  \
# Missing Ratio     0.497512      0.39801  0.39801       0.39801      0.39801
#
#                Loss of interest  Fun with friends     Cars  HouseFlats  \
# Missing Ratio           0.39801           0.39801  0.39801     0.39801
#
#                Funniness  Decision making    Dance  Hiphop, Rap  \
# Missing Ratio    0.39801          0.39801  0.39801      0.39801
#
#                Questionnaires or polls  Finding lost valuables  Personality  \
# Missing Ratio                  0.39801                 0.39801      0.39801
#
#                Small - big dogs  Happiness in life  Getting angry  Children  \
# Missing Ratio           0.39801            0.39801        0.39801   0.39801
#
#                Mood swings  Western  Internet  Cheating in school  \
# Missing Ratio      0.39801  0.39801   0.39801             0.39801
#
#                Hypochondria  Judgment calls  Romantic    Comedy  \
# Missing Ratio       0.39801         0.39801  0.298507  0.298507
#
#                Fantasy/Fairy tales  Animated  Religion   Physics   Dancing  \
# Missing Ratio             0.298507  0.298507  0.298507  0.298507  0.298507
#
#                Metal or Hardrock       Pop  Mathematics     Music  \
# Missing Ratio           0.298507  0.298507     0.298507  0.298507
#
#                Appearence and gestures  Spending on looks  Life struggles  \
# Missing Ratio                 0.298507           0.298507        0.298507
#
#                Interests or hobbies   Charity  Finances  Elections  \
# Missing Ratio              0.298507  0.298507  0.298507   0.298507
#
#                Thinking ahead  Writing notes  Healthy eating  \
# Missing Ratio        0.298507       0.298507        0.298507
#
#                Entertainment spending      Rats   Heights  LeftRightHanded  \
# Missing Ratio                0.298507  0.298507  0.298507         0.298507
#
#                 Waiting    Flying  Adrenaline sports  Unpopularity  \
# Missing Ratio  0.298507  0.298507           0.298507      0.298507
#
#                Public speaking    Horror  Assertiveness  \
# Missing Ratio         0.199005  0.199005       0.199005
#
#                Knowing the right people  Achievements  Celebrities  \
# Missing Ratio                  0.199005      0.199005     0.199005
#
#                Parents' advice  Shopping centres    Sci-fi  \
# Missing Ratio         0.199005          0.199005  0.199005
#
#                Spending on healthy eating  OnlyChild  \
# Missing Ratio                    0.199005   0.199005
#
#                Slow songs or fast songs  Branded clothing     Lying       War  \
# Missing Ratio                  0.199005          0.199005  0.199005  0.199005
#
#                Shopping  Punctuality    Action   History       God  \
# Missing Ratio  0.199005     0.199005  0.199005  0.199005  0.199005
#
#                Changing the past  Darkness  New environment  Borrowed stuff  \
# Missing Ratio           0.199005  0.199005         0.199005        0.199005
#
#                Dangerous dogs     Storm  Musical instruments  Education  \
# Missing Ratio        0.099502  0.099502             0.099502   0.099502
#
#                  Ageing   Musical  Loneliness       Law  Keeping promises  \
# Missing Ratio  0.099502  0.099502    0.099502  0.099502          0.099502
#
#                    Fake    Health  Politics     Opera  Thriller  \
# Missing Ratio  0.099502  0.099502  0.099502  0.099502  0.099502
#
#                Fear of public speaking
# Missing Ratio                 0.099502

# %% [markdown]
# The percentage of missing values is not a lot, we can easily impute them without introducing too much bias by using the mode

# %%
df[all_columns]=df[all_columns].fillna(df.mode().iloc[0])

# %%
df.isnull().any().any()
# Out:
# False

# %% [markdown]
# There are no missing values now

# %% [markdown]
# ### Data types

# %%
df.dtypes[:10]
# Out:
# Music                       float64
# Slow songs or fast songs    float64
# Dance                       float64
# Folk                        float64
# Country                     float64
# Classical music             float64
# Musical                     float64
# Pop                         float64
# Rock                        float64
# Metal or Hardrock           float64
# dtype: object

# %%
float_cols = df.dtypes == np.float64

# %%
fake_float = list(df.loc[:, float_cols])

# %%
len(fake_float)
# Out:
# 134

# %% [markdown]
# 134 columns are float but should be int since the decimal value is always 0, let's convert them

# %%
df[fake_float] = df[fake_float].astype(int)

# %% [markdown]
# ## One hot encoding for categorical features
# Since the algorithms that I have in mind do not handle categorical values I will need to perform one hot encoding or encode values in numbers for ordinal data
#
# Let's look at categorical columns and decide which ones can be ordinal

# %%
categorical = df.dtypes == np.object

# %%
df.loc[:, categorical].T
# Out:
#                                     0                        1     \
# Smoking                     never smoked             never smoked
# Alcohol                      drink a lot              drink a lot
# Punctuality          i am always on time         i am often early
# Lying                              never                sometimes
# InternetUsage            few hours a day          few hours a day
# Gender                            female                   female
# LeftRightHanded             right handed             right handed
# Education        college/bachelor degree  college/bachelor degree
# OnlyChild                             no                       no
# VillageTown                      village                     city
# HouseFlats                block of flats           block of flats
#
#                                     2                              3     \
# Smoking                    tried smoking                  former smoker
# Alcohol                      drink a lot                    drink a lot
# Punctuality      i am often running late               i am often early
# Lying                          sometimes  only to avoid hurting someone
# InternetUsage            few hours a day                most of the day
# Gender                            female                         female
# LeftRightHanded             right handed                   right handed
# Education               secondary school        college/bachelor degree
# OnlyChild                             no                            yes
# VillageTown                         city                           city
# HouseFlats                block of flats                 house/bungalow
#
#                                   4                              5     \
# Smoking                  tried smoking                   never smoked
# Alcohol                 social drinker                          never
# Punctuality        i am always on time               i am often early
# Lying            everytime it suits me  only to avoid hurting someone
# InternetUsage          few hours a day                few hours a day
# Gender                          female                           male
# LeftRightHanded           right handed                   right handed
# Education             secondary school               secondary school
# OnlyChild                           no                             no
# VillageTown                    village                           city
# HouseFlats              house/bungalow                 block of flats
#
#                                     6                        7     \
# Smoking                    tried smoking           current smoker
# Alcohol                   social drinker              drink a lot
# Punctuality             i am often early      i am always on time
# Lying                              never                sometimes
# InternetUsage    less than an hour a day          few hours a day
# Gender                            female                     male
# LeftRightHanded             right handed             right handed
# Education               secondary school  college/bachelor degree
# OnlyChild                             no                       no
# VillageTown                      village                     city
# HouseFlats                house/bungalow           house/bungalow
#
#                              8                        9     \
# Smoking             tried smoking             never smoked
# Alcohol            social drinker              drink a lot
# Punctuality      i am often early  i am often running late
# Lying                   sometimes                sometimes
# InternetUsage     few hours a day          few hours a day
# Gender                     female                   female
# LeftRightHanded      right handed             right handed
# Education        secondary school         secondary school
# OnlyChild                      no                       no
# VillageTown                  city                     city
# HouseFlats         house/bungalow           block of flats
#
#                                     10                       11    \
# Smoking                   current smoker            tried smoking
# Alcohol                   social drinker                    never
# Punctuality             i am often early  i am often running late
# Lying                          sometimes    everytime it suits me
# InternetUsage    less than an hour a day          few hours a day
# Gender                            female                   female
# LeftRightHanded              left handed             right handed
# Education               secondary school           primary school
# OnlyChild                             no                       no
# VillageTown                         city                     city
# HouseFlats                block of flats           block of flats
#
#                                           12                             13    \
# Smoking                          tried smoking                   never smoked
# Alcohol                         social drinker                 social drinker
# Punctuality            i am often running late               i am often early
# Lying            only to avoid hurting someone  only to avoid hurting someone
# InternetUsage                  few hours a day                few hours a day
# Gender                                  female                         female
# LeftRightHanded                   right handed                   right handed
# Education              college/bachelor degree               secondary school
# OnlyChild                                   no                             no
# VillageTown                               city                           city
# HouseFlats                      block of flats                 block of flats
#
#                                           14                             15    \
# Smoking                         current smoker                  former smoker
# Alcohol                         social drinker                 social drinker
# Punctuality                   i am often early            i am always on time
# Lying            only to avoid hurting someone  only to avoid hurting someone
# InternetUsage                  most of the day                few hours a day
# Gender                                  female                           male
# LeftRightHanded                   right handed                   right handed
# Education              college/bachelor degree               secondary school
# OnlyChild                                   no                            yes
# VillageTown                               city                           city
# HouseFlats                      block of flats                 block of flats
#
#                                     16                       17    \
# Smoking                   current smoker            tried smoking
# Alcohol                      drink a lot           social drinker
# Punctuality          i am always on time  i am often running late
# Lying              everytime it suits me    everytime it suits me
# InternetUsage            few hours a day          few hours a day
# Gender                            female                   female
# LeftRightHanded             right handed             right handed
# Education        college/bachelor degree         secondary school
# OnlyChild                             no                       no
# VillageTown                         city                  village
# HouseFlats                block of flats           house/bungalow
#
#                                           18                             19    \
# Smoking                          tried smoking                  former smoker
# Alcohol                         social drinker                    drink a lot
# Punctuality                   i am often early            i am always on time
# Lying            only to avoid hurting someone  only to avoid hurting someone
# InternetUsage                  few hours a day                few hours a day
# Gender                                    male                           male
# LeftRightHanded                   right handed                    left handed
# Education                     secondary school               secondary school
# OnlyChild                                   no                             no
# VillageTown                               city                           city
# HouseFlats                      house/bungalow                 house/bungalow
#
#                                           20                21    \
# Smoking                           never smoked     tried smoking
# Alcohol                                  never    social drinker
# Punctuality                   i am often early  i am often early
# Lying            only to avoid hurting someone         sometimes
# InternetUsage                  few hours a day   few hours a day
# Gender                                    male              male
# LeftRightHanded                   right handed       left handed
# Education                     secondary school  secondary school
# OnlyChild                                   no                no
# VillageTown                               city              city
# HouseFlats                      block of flats    block of flats
#
#                                     22                       23    \
# Smoking                    tried smoking            tried smoking
# Alcohol                   social drinker           social drinker
# Punctuality             i am often early  i am often running late
# Lying                          sometimes                sometimes
# InternetUsage            few hours a day          few hours a day
# Gender                            female                   female
# LeftRightHanded             right handed             right handed
# Education        college/bachelor degree         secondary school
# OnlyChild                             no                       no
# VillageTown                         city                     city
# HouseFlats                house/bungalow           block of flats
#
#                                           24                   25    \
# Smoking                          tried smoking        tried smoking
# Alcohol                                  never       social drinker
# Punctuality                   i am often early  i am always on time
# Lying            only to avoid hurting someone            sometimes
# InternetUsage                  few hours a day      few hours a day
# Gender                                  female               female
# LeftRightHanded                   right handed         right handed
# Education                     secondary school     secondary school
# OnlyChild                                   no                  yes
# VillageTown                               city                 city
# HouseFlats                      block of flats       block of flats
#
#                                     26                27    \
# Smoking                    tried smoking      never smoked
# Alcohol                   social drinker    social drinker
# Punctuality             i am often early  i am often early
# Lying                          sometimes         sometimes
# InternetUsage            few hours a day   few hours a day
# Gender                            female            female
# LeftRightHanded              left handed      right handed
# Education        college/bachelor degree  secondary school
# OnlyChild                             no                no
# VillageTown                         city              city
# HouseFlats                house/bungalow    house/bungalow
#
#                                 28                       29    \
# Smoking                former smoker            tried smoking
# Alcohol               social drinker           social drinker
# Punctuality      i am always on time  i am often running late
# Lying                      sometimes                sometimes
# InternetUsage        few hours a day          few hours a day
# Gender                          male                   female
# LeftRightHanded          left handed             right handed
# Education           secondary school         secondary school
# OnlyChild                        yes                       no
# VillageTown                  village                  village
# HouseFlats            house/bungalow           block of flats
#
#                                   30                       31    \
# Smoking                  former smoker            tried smoking
# Alcohol                    drink a lot           social drinker
# Punctuality        i am always on time      i am always on time
# Lying            everytime it suits me                sometimes
# InternetUsage          few hours a day  less than an hour a day
# Gender                            male                   female
# LeftRightHanded           right handed             right handed
# Education             secondary school         secondary school
# OnlyChild                           no                       no
# VillageTown                       city                     city
# HouseFlats              block of flats           block of flats
#
#                                           32                33    \
# Smoking                         current smoker     tried smoking
# Alcohol                         social drinker    social drinker
# Punctuality                i am always on time  i am often early
# Lying            only to avoid hurting someone         sometimes
# InternetUsage                  few hours a day   few hours a day
# Gender                                  female            female
# LeftRightHanded                    left handed      right handed
# Education                     secondary school    masters degree
# OnlyChild                                   no                no
# VillageTown                               city              city
# HouseFlats                      block of flats    block of flats
#
#                                     34                   35    \
# Smoking                    tried smoking        tried smoking
# Alcohol                   social drinker       social drinker
# Punctuality             i am often early  i am always on time
# Lying                          sometimes            sometimes
# InternetUsage            few hours a day      few hours a day
# Gender                              male               female
# LeftRightHanded             right handed         right handed
# Education        college/bachelor degree     secondary school
# OnlyChild                             no                   no
# VillageTown                         city              village
# HouseFlats                block of flats       house/bungalow
#
#                                           36                37    \
# Smoking                           never smoked     former smoker
# Alcohol                         social drinker    social drinker
# Punctuality                   i am often early  i am often early
# Lying            only to avoid hurting someone         sometimes
# InternetUsage                  few hours a day   few hours a day
# Gender                                  female              male
# LeftRightHanded                   right handed      right handed
# Education                     secondary school  secondary school
# OnlyChild                                   no                no
# VillageTown                               city              city
# HouseFlats                      block of flats    block of flats
#
#                                           38                39    \
# Smoking                          tried smoking      never smoked
# Alcohol                         social drinker             never
# Punctuality            i am often running late  i am often early
# Lying            only to avoid hurting someone         sometimes
# InternetUsage                  few hours a day   few hours a day
# Gender                                  female            female
# LeftRightHanded                   right handed      right handed
# Education                     secondary school  secondary school
# OnlyChild                                   no                no
# VillageTown                            village              city
# HouseFlats                      house/bungalow    house/bungalow
#
#                                           40                       41    \
# Smoking                           never smoked            tried smoking
# Alcohol                         social drinker           social drinker
# Punctuality                   i am often early  i am often running late
# Lying            only to avoid hurting someone                    never
# InternetUsage                  few hours a day          few hours a day
# Gender                                  female                     male
# LeftRightHanded                   right handed             right handed
# Education                     secondary school  college/bachelor degree
# OnlyChild                                   no                       no
# VillageTown                               city                     city
# HouseFlats                      block of flats           block of flats
#
#                              42                             43    \
# Smoking              never smoked                  tried smoking
# Alcohol                     never                    drink a lot
# Punctuality      i am often early            i am always on time
# Lying                   sometimes  only to avoid hurting someone
# InternetUsage     few hours a day                most of the day
# Gender                     female                         female
# LeftRightHanded      right handed                   right handed
# Education        secondary school        college/bachelor degree
# OnlyChild                     yes                             no
# VillageTown                  city                           city
# HouseFlats         block of flats                 block of flats
#
#                                           44                45    \
# Smoking                         current smoker      never smoked
# Alcohol                         social drinker    social drinker
# Punctuality                   i am often early  i am often early
# Lying            only to avoid hurting someone             never
# InternetUsage                  few hours a day   most of the day
# Gender                                  female              male
# LeftRightHanded                   right handed      right handed
# Education                       masters degree    masters degree
# OnlyChild                                   no                no
# VillageTown                            village              city
# HouseFlats                      block of flats    block of flats
#
#                                     46                   47    \
# Smoking                   current smoker        tried smoking
# Alcohol                   social drinker       social drinker
# Punctuality          i am always on time  i am always on time
# Lying                          sometimes            sometimes
# InternetUsage            few hours a day      few hours a day
# Gender                            female               female
# LeftRightHanded             right handed         right handed
# Education        college/bachelor degree     secondary school
# OnlyChild                             no                  yes
# VillageTown                         city                 city
# HouseFlats                block of flats       house/bungalow
#
#                                           48                49    \
# Smoking                         current smoker     tried smoking
# Alcohol                         social drinker    social drinker
# Punctuality                   i am often early  i am often early
# Lying            only to avoid hurting someone         sometimes
# InternetUsage                  few hours a day   few hours a day
# Gender                                  female            female
# LeftRightHanded                   right handed      right handed
# Education                     secondary school    primary school
# OnlyChild                                  yes                no
# VillageTown                            village              city
# HouseFlats                      house/bungalow    block of flats
#
#                                           50                       51    \
# Smoking                          tried smoking             never smoked
# Alcohol                         social drinker                    never
# Punctuality            i am often running late      i am always on time
# Lying            only to avoid hurting someone                sometimes
# InternetUsage                  few hours a day  less than an hour a day
# Gender                                  female                   female
# LeftRightHanded                   right handed             right handed
# Education              college/bachelor degree         secondary school
# OnlyChild                                   no                       no
# VillageTown                               city                     city
# HouseFlats                      block of flats           block of flats
#
#                              52                             53    \
# Smoking            current smoker                  tried smoking
# Alcohol            social drinker                 social drinker
# Punctuality      i am often early            i am always on time
# Lying                   sometimes  only to avoid hurting someone
# InternetUsage     few hours a day        less than an hour a day
# Gender                     female                         female
# LeftRightHanded      right handed                   right handed
# Education        secondary school               secondary school
# OnlyChild                      no                             no
# VillageTown               village                           city
# HouseFlats         block of flats                 block of flats
#
#                                     54                       55    \
# Smoking                   current smoker           current smoker
# Alcohol                   social drinker              drink a lot
# Punctuality          i am always on time         i am often early
# Lying                          sometimes                sometimes
# InternetUsage            few hours a day          few hours a day
# Gender                            female                   female
# LeftRightHanded             right handed             right handed
# Education        college/bachelor degree  college/bachelor degree
# OnlyChild                             no                       no
# VillageTown                         city                  village
# HouseFlats                block of flats           house/bungalow
#
#                                     56                   57    \
# Smoking                   current smoker       current smoker
# Alcohol                      drink a lot          drink a lot
# Punctuality      i am often running late  i am always on time
# Lying                          sometimes            sometimes
# InternetUsage            few hours a day      few hours a day
# Gender                            female               female
# LeftRightHanded              left handed         right handed
# Education               secondary school     secondary school
# OnlyChild                             no                   no
# VillageTown                         city                 city
# HouseFlats                block of flats       block of flats
#
#                                     58                       59    \
# Smoking                     never smoked           current smoker
# Alcohol                   social drinker              drink a lot
# Punctuality      i am often running late         i am often early
# Lying              everytime it suits me    everytime it suits me
# InternetUsage            few hours a day          few hours a day
# Gender                              male                     male
# LeftRightHanded             right handed             right handed
# Education               secondary school  college/bachelor degree
# OnlyChild                             no                       no
# VillageTown                      village                     city
# HouseFlats                house/bungalow           block of flats
#
#                                     60                             61    \
# Smoking                    tried smoking                 current smoker
# Alcohol                   social drinker                 social drinker
# Punctuality          i am always on time            i am always on time
# Lying                          sometimes  only to avoid hurting someone
# InternetUsage            most of the day                few hours a day
# Gender                              male                           male
# LeftRightHanded             right handed                    left handed
# Education        college/bachelor degree               secondary school
# OnlyChild                             no                             no
# VillageTown                         city                           city
# HouseFlats                block of flats                 block of flats
#
#                                           62                       63    \
# Smoking                           never smoked            tried smoking
# Alcohol                         social drinker           social drinker
# Punctuality                i am always on time      i am always on time
# Lying            only to avoid hurting someone                sometimes
# InternetUsage                  few hours a day          few hours a day
# Gender                                    male                     male
# LeftRightHanded                   right handed             right handed
# Education                     secondary school  college/bachelor degree
# OnlyChild                                   no                       no
# VillageTown                               city                     city
# HouseFlats                      block of flats           block of flats
#
#                                           64                     65    \
# Smoking                          former smoker          tried smoking
# Alcohol                         social drinker         social drinker
# Punctuality            i am often running late       i am often early
# Lying            only to avoid hurting someone  everytime it suits me
# InternetUsage                  most of the day        few hours a day
# Gender                                  female                   male
# LeftRightHanded                   right handed            left handed
# Education                       primary school         primary school
# OnlyChild                                  yes                    yes
# VillageTown                               city                   city
# HouseFlats                      block of flats         block of flats
#
#                                     66                             67    \
# Smoking                    tried smoking                   never smoked
# Alcohol                   social drinker                          never
# Punctuality             i am often early               i am often early
# Lying                          sometimes  only to avoid hurting someone
# InternetUsage    less than an hour a day                few hours a day
# Gender                              male                         female
# LeftRightHanded             right handed                   right handed
# Education               secondary school        college/bachelor degree
# OnlyChild                             no                            yes
# VillageTown                      village                        village
# HouseFlats                house/bungalow                 house/bungalow
#
#                                     68                       69    \
# Smoking                    tried smoking            tried smoking
# Alcohol                      drink a lot           social drinker
# Punctuality             i am often early  i am often running late
# Lying                          sometimes    everytime it suits me
# InternetUsage            few hours a day          most of the day
# Gender                            female                   female
# LeftRightHanded             right handed              left handed
# Education        college/bachelor degree         secondary school
# OnlyChild                             no                       no
# VillageTown                      village                     city
# HouseFlats                house/bungalow           block of flats
#
#                                 70                       71    \
# Smoking                former smoker            tried smoking
# Alcohol               social drinker                    never
# Punctuality      i am always on time  i am often running late
# Lying                          never                sometimes
# InternetUsage        few hours a day          few hours a day
# Gender                          male                     male
# LeftRightHanded         right handed              left handed
# Education           secondary school         secondary school
# OnlyChild                        yes                      yes
# VillageTown                     city                     city
# HouseFlats            house/bungalow           block of flats
#
#                                   72                     73    \
# Smoking                  former smoker          former smoker
# Alcohol                 social drinker         social drinker
# Punctuality        i am always on time    i am always on time
# Lying            everytime it suits me  everytime it suits me
# InternetUsage          few hours a day        few hours a day
# Gender                          female                   male
# LeftRightHanded           right handed           right handed
# Education             secondary school       secondary school
# OnlyChild                           no                    yes
# VillageTown                       city                   city
# HouseFlats              block of flats         house/bungalow
#
#                                 74             ...             \
# Smoking                tried smoking           ...
# Alcohol               social drinker           ...
# Punctuality      i am always on time           ...
# Lying                      sometimes           ...
# InternetUsage        few hours a day           ...
# Gender                          male           ...
# LeftRightHanded         right handed           ...
# Education             masters degree           ...
# OnlyChild                         no           ...
# VillageTown                     city           ...
# HouseFlats            block of flats           ...
#
#                                     935               936   \
# Smoking                    tried smoking     tried smoking
# Alcohol                   social drinker    social drinker
# Punctuality      i am often running late  i am often early
# Lying                          sometimes             never
# InternetUsage            few hours a day   few hours a day
# Gender                            female            female
# LeftRightHanded             right handed      right handed
# Education               secondary school  secondary school
# OnlyChild                             no               yes
# VillageTown                         city              city
# HouseFlats                block of flats    block of flats
#
#                                     937                      938   \
# Smoking                     never smoked            former smoker
# Alcohol                   social drinker           social drinker
# Punctuality      i am often running late  i am often running late
# Lying                          sometimes    everytime it suits me
# InternetUsage            few hours a day          few hours a day
# Gender                            female                   female
# LeftRightHanded             right handed             right handed
# Education                 primary school         secondary school
# OnlyChild                            yes                      yes
# VillageTown                      village                     city
# HouseFlats                house/bungalow           house/bungalow
#
#                                           939                      940   \
# Smoking                           never smoked            tried smoking
# Alcohol                                  never                    never
# Punctuality                i am always on time  i am often running late
# Lying            only to avoid hurting someone                sometimes
# InternetUsage                  few hours a day          few hours a day
# Gender                                  female                     male
# LeftRightHanded                   right handed             right handed
# Education                     secondary school           primary school
# OnlyChild                                  yes                       no
# VillageTown                               city                     city
# HouseFlats                      block of flats           block of flats
#
#                                     941                            942   \
# Smoking                   current smoker                  tried smoking
# Alcohol                   social drinker                    drink a lot
# Punctuality      i am often running late               i am often early
# Lying              everytime it suits me  only to avoid hurting someone
# InternetUsage            few hours a day                most of the day
# Gender                            female                           male
# LeftRightHanded             right handed                   right handed
# Education                 primary school        college/bachelor degree
# OnlyChild                             no                            yes
# VillageTown                      village                        village
# HouseFlats                house/bungalow                 house/bungalow
#
#                                           943                      944   \
# Smoking                         current smoker             never smoked
# Alcohol                         social drinker           social drinker
# Punctuality                   i am often early  i am often running late
# Lying            only to avoid hurting someone                sometimes
# InternetUsage          less than an hour a day          few hours a day
# Gender                                  female                   female
# LeftRightHanded                   right handed             right handed
# Education                     secondary school         secondary school
# OnlyChild                                   no                       no
# VillageTown                               city                  village
# HouseFlats                      block of flats           house/bungalow
#
#                                   945                            946   \
# Smoking                 current smoker                  tried smoking
# Alcohol                    drink a lot                 social drinker
# Punctuality           i am often early               i am often early
# Lying            everytime it suits me  only to avoid hurting someone
# InternetUsage          few hours a day                few hours a day
# Gender                            male                           male
# LeftRightHanded           right handed                   right handed
# Education             secondary school               secondary school
# OnlyChild                           no                            yes
# VillageTown                       city                           city
# HouseFlats              block of flats                 house/bungalow
#
#                                           947               948   \
# Smoking                          tried smoking     tried smoking
# Alcohol                         social drinker    social drinker
# Punctuality                   i am often early  i am often early
# Lying            only to avoid hurting someone         sometimes
# InternetUsage                  few hours a day   few hours a day
# Gender                                  female            female
# LeftRightHanded                   right handed      right handed
# Education                     secondary school  secondary school
# OnlyChild                                  yes                no
# VillageTown                            village           village
# HouseFlats                      house/bungalow    house/bungalow
#
#                                   949                               950   \
# Smoking                  tried smoking                      never smoked
# Alcohol                 social drinker                             never
# Punctuality           i am often early               i am always on time
# Lying            everytime it suits me                         sometimes
# InternetUsage          most of the day                   most of the day
# Gender                          female                              male
# LeftRightHanded           right handed                       left handed
# Education             secondary school  currently a primary school pupil
# OnlyChild                           no                               yes
# VillageTown                       city                           village
# HouseFlats              block of flats                    house/bungalow
#
#                                     951                            952   \
# Smoking                    former smoker                   never smoked
# Alcohol                      drink a lot                          never
# Punctuality      i am often running late               i am often early
# Lying              everytime it suits me  only to avoid hurting someone
# InternetUsage            most of the day                few hours a day
# Gender                              male                           male
# LeftRightHanded             right handed                   right handed
# Education                 masters degree               secondary school
# OnlyChild                             no                            yes
# VillageTown                         city                           city
# HouseFlats                block of flats                 block of flats
#
#                                 953                    954               955   \
# Smoking                tried smoking          former smoker    current smoker
# Alcohol               social drinker         social drinker       drink a lot
# Punctuality      i am always on time    i am always on time  i am often early
# Lying                      sometimes  everytime it suits me         sometimes
# InternetUsage        few hours a day        few hours a day   few hours a day
# Gender                        female                 female            female
# LeftRightHanded         right handed           right handed      right handed
# Education           secondary school       secondary school  secondary school
# OnlyChild                         no                     no                no
# VillageTown                     city                   city              city
# HouseFlats            block of flats         block of flats    block of flats
#
#                                   956                      957   \
# Smoking                 current smoker             never smoked
# Alcohol                    drink a lot           social drinker
# Punctuality        i am always on time  i am often running late
# Lying            everytime it suits me                sometimes
# InternetUsage          most of the day          few hours a day
# Gender                            male                     male
# LeftRightHanded           right handed             right handed
# Education             secondary school         secondary school
# OnlyChild                          yes                       no
# VillageTown                       city                     city
# HouseFlats              house/bungalow           block of flats
#
#                                           958                  959   \
# Smoking                          tried smoking       current smoker
# Alcohol                         social drinker       social drinker
# Punctuality                   i am often early  i am always on time
# Lying            only to avoid hurting someone            sometimes
# InternetUsage                  few hours a day      few hours a day
# Gender                                  female               female
# LeftRightHanded                   right handed          left handed
# Education              college/bachelor degree       masters degree
# OnlyChild                                   no                   no
# VillageTown                               city                 city
# HouseFlats                      block of flats       block of flats
#
#                                     960                    961   \
# Smoking                     never smoked          tried smoking
# Alcohol                   social drinker         social drinker
# Punctuality      i am often running late    i am always on time
# Lying                          sometimes  everytime it suits me
# InternetUsage            few hours a day        few hours a day
# Gender                            female                   male
# LeftRightHanded             right handed            left handed
# Education                 masters degree       secondary school
# OnlyChild                             no                     no
# VillageTown                         city                village
# HouseFlats                block of flats         house/bungalow
#
#                                     962                      963   \
# Smoking                     never smoked           current smoker
# Alcohol                            never           social drinker
# Punctuality             i am often early  i am often running late
# Lying                              never                sometimes
# InternetUsage    less than an hour a day          most of the day
# Gender                            female                     male
# LeftRightHanded             right handed              left handed
# Education               secondary school         secondary school
# OnlyChild                             no                      yes
# VillageTown                      village                     city
# HouseFlats                house/bungalow           block of flats
#
#                                     964                      965   \
# Smoking                    tried smoking            tried smoking
# Alcohol                   social drinker           social drinker
# Punctuality          i am always on time  i am often running late
# Lying                          sometimes    everytime it suits me
# InternetUsage            few hours a day          few hours a day
# Gender                              male                   female
# LeftRightHanded             right handed             right handed
# Education        college/bachelor degree           primary school
# OnlyChild                            yes                       no
# VillageTown                         city                     city
# HouseFlats                block of flats           block of flats
#
#                                     966                            967   \
# Smoking                    tried smoking                   never smoked
# Alcohol                   social drinker                 social drinker
# Punctuality      i am often running late            i am always on time
# Lying              everytime it suits me  only to avoid hurting someone
# InternetUsage    less than an hour a day                few hours a day
# Gender                            female                           male
# LeftRightHanded              left handed                   right handed
# Education        college/bachelor degree                 primary school
# OnlyChild                             no                             no
# VillageTown                         city                           city
# HouseFlats                house/bungalow                 block of flats
#
#                                 968                      969   \
# Smoking                tried smoking            former smoker
# Alcohol               social drinker              drink a lot
# Punctuality      i am always on time  i am often running late
# Lying                      sometimes    everytime it suits me
# InternetUsage        few hours a day          few hours a day
# Gender                          male                     male
# LeftRightHanded          left handed             right handed
# Education           secondary school  college/bachelor degree
# OnlyChild                         no                       no
# VillageTown                     city                  village
# HouseFlats            house/bungalow           block of flats
#
#                                   970                      971   \
# Smoking                 current smoker            tried smoking
# Alcohol                    drink a lot           social drinker
# Punctuality           i am often early  i am often running late
# Lying            everytime it suits me                sometimes
# InternetUsage          few hours a day          few hours a day
# Gender                            male                     male
# LeftRightHanded           right handed             right handed
# Education               masters degree         secondary school
# OnlyChild                           no                       no
# VillageTown                       city                     city
# HouseFlats              block of flats           block of flats
#
#                                           972               973   \
# Smoking                          tried smoking    current smoker
# Alcohol                         social drinker    social drinker
# Punctuality                i am always on time  i am often early
# Lying            only to avoid hurting someone         sometimes
# InternetUsage          less than an hour a day   most of the day
# Gender                                  female            female
# LeftRightHanded                   right handed      right handed
# Education                     secondary school  secondary school
# OnlyChild                                  yes                no
# VillageTown                               city              city
# HouseFlats                      block of flats    block of flats
#
#                                   974                      975   \
# Smoking                 current smoker           current smoker
# Alcohol                    drink a lot              drink a lot
# Punctuality           i am often early  i am often running late
# Lying            everytime it suits me    everytime it suits me
# InternetUsage          few hours a day          most of the day
# Gender                          female                   female
# LeftRightHanded           right handed             right handed
# Education             secondary school         secondary school
# OnlyChild                          yes                      yes
# VillageTown                       city                  village
# HouseFlats              block of flats           block of flats
#
#                                 976                    977   \
# Smoking                tried smoking         current smoker
# Alcohol               social drinker            drink a lot
# Punctuality      i am always on time    i am always on time
# Lying                      sometimes  everytime it suits me
# InternetUsage        few hours a day        few hours a day
# Gender                        female                   male
# LeftRightHanded         right handed           right handed
# Education           secondary school       secondary school
# OnlyChild                        yes                     no
# VillageTown                     city                village
# HouseFlats            block of flats         house/bungalow
#
#                                           978                      979   \
# Smoking                          tried smoking             never smoked
# Alcohol                         social drinker           social drinker
# Punctuality                i am always on time  i am often running late
# Lying            only to avoid hurting someone                sometimes
# InternetUsage                  few hours a day          few hours a day
# Gender                                  female                     male
# LeftRightHanded                   right handed              left handed
# Education              college/bachelor degree         secondary school
# OnlyChild                                   no                      yes
# VillageTown                               city                     city
# HouseFlats                      house/bungalow           block of flats
#
#                                     980                  981   \
# Smoking                    tried smoking        tried smoking
# Alcohol                      drink a lot       social drinker
# Punctuality             i am often early  i am always on time
# Lying                          sometimes            sometimes
# InternetUsage    less than an hour a day      most of the day
# Gender                            female               female
# LeftRightHanded             right handed          left handed
# Education               secondary school     secondary school
# OnlyChild                             no                   no
# VillageTown                         city              village
# HouseFlats                house/bungalow       house/bungalow
#
#                                     982                            983   \
# Smoking                    tried smoking                  tried smoking
# Alcohol                      drink a lot                 social drinker
# Punctuality      i am often running late            i am always on time
# Lying                          sometimes  only to avoid hurting someone
# InternetUsage            few hours a day                few hours a day
# Gender                              male                         female
# LeftRightHanded             right handed                   right handed
# Education               secondary school               secondary school
# OnlyChild                             no                             no
# VillageTown                         city                        village
# HouseFlats                house/bungalow                 house/bungalow
#
#                                     984                  985   \
# Smoking                   current smoker        former smoker
# Alcohol                      drink a lot       social drinker
# Punctuality      i am often running late  i am always on time
# Lying                          sometimes            sometimes
# InternetUsage            most of the day      few hours a day
# Gender                            female               female
# LeftRightHanded             right handed         right handed
# Education               secondary school     secondary school
# OnlyChild                            yes                   no
# VillageTown                         city                 city
# HouseFlats                block of flats       block of flats
#
#                                     986                      987   \
# Smoking                    tried smoking           current smoker
# Alcohol                   social drinker              drink a lot
# Punctuality      i am often running late  i am often running late
# Lying                          sometimes                sometimes
# InternetUsage            few hours a day          few hours a day
# Gender                            female                     male
# LeftRightHanded             right handed             right handed
# Education               secondary school         secondary school
# OnlyChild                             no                       no
# VillageTown                         city                     city
# HouseFlats                house/bungalow           block of flats
#
#                                           988               989   \
# Smoking                          tried smoking     former smoker
# Alcohol                            drink a lot       drink a lot
# Punctuality            i am often running late  i am often early
# Lying            only to avoid hurting someone         sometimes
# InternetUsage                  few hours a day   most of the day
# Gender                                    male            female
# LeftRightHanded                   right handed      right handed
# Education                     secondary school    masters degree
# OnlyChild                                  yes                no
# VillageTown                               city           village
# HouseFlats                      block of flats    house/bungalow
#
#                                     990                      991   \
# Smoking                    former smoker            tried smoking
# Alcohol                   social drinker           social drinker
# Punctuality      i am often running late  i am often running late
# Lying                          sometimes                sometimes
# InternetUsage            few hours a day          most of the day
# Gender                              male                     male
# LeftRightHanded             right handed             right handed
# Education               secondary school         secondary school
# OnlyChild                             no                      yes
# VillageTown                         city                     city
# HouseFlats                block of flats           house/bungalow
#
#                                           992                    993   \
# Smoking                           never smoked          former smoker
# Alcohol                                  never         social drinker
# Punctuality                   i am often early       i am often early
# Lying            only to avoid hurting someone  everytime it suits me
# InternetUsage                  most of the day        few hours a day
# Gender                                    male                 female
# LeftRightHanded                   right handed           right handed
# Education                       masters degree       secondary school
# OnlyChild                                   no                    yes
# VillageTown                               city                   city
# HouseFlats                      block of flats         block of flats
#
#                                     994                            995   \
# Smoking                   current smoker                  tried smoking
# Alcohol                      drink a lot                          never
# Punctuality      i am often running late               i am often early
# Lying                          sometimes  only to avoid hurting someone
# InternetUsage            few hours a day                few hours a day
# Gender                            female                         female
# LeftRightHanded             right handed                   right handed
# Education               secondary school               secondary school
# OnlyChild                            yes                            yes
# VillageTown                         city                           city
# HouseFlats                block of flats                 block of flats
#
#                                 996                      997   \
# Smoking                former smoker            tried smoking
# Alcohol               social drinker           social drinker
# Punctuality      i am always on time  i am often running late
# Lying                      sometimes                sometimes
# InternetUsage        few hours a day  less than an hour a day
# Gender                          male                   female
# LeftRightHanded         right handed             right handed
# Education           secondary school         secondary school
# OnlyChild                        yes                       no
# VillageTown                     city                     city
# HouseFlats            block of flats           block of flats
#
#                                 998                            999   \
# Smoking                tried smoking                   never smoked
# Alcohol               social drinker                 social drinker
# Punctuality      i am always on time            i am always on time
# Lying                      sometimes  only to avoid hurting someone
# InternetUsage        few hours a day                few hours a day
# Gender                          male                           male
# LeftRightHanded         right handed                   right handed
# Education             masters degree               secondary school
# OnlyChild                         no                             no
# VillageTown                     city                           city
# HouseFlats            block of flats                 block of flats
#
#                                 1000                 1001  \
# Smoking                 never smoked        former smoker
# Alcohol                        never                never
# Punctuality      i am always on time  i am always on time
# Lying                      sometimes            sometimes
# InternetUsage        few hours a day      few hours a day
# Gender                        female               female
# LeftRightHanded         right handed         right handed
# Education             primary school       primary school
# OnlyChild                         no                   no
# VillageTown                     city                 city
# HouseFlats            block of flats       block of flats
#
#                                     1002                 1003  \
# Smoking                   current smoker        former smoker
# Alcohol                   social drinker       social drinker
# Punctuality      i am often running late  i am always on time
# Lying              everytime it suits me            sometimes
# InternetUsage            few hours a day      few hours a day
# Gender                              male               female
# LeftRightHanded             right handed         right handed
# Education               secondary school     secondary school
# OnlyChild                             no                   no
# VillageTown                         city                 city
# HouseFlats                block of flats       house/bungalow
#
#                                     1004                     1005  \
# Smoking                    former smoker           current smoker
# Alcohol                   social drinker              drink a lot
# Punctuality      i am often running late  i am often running late
# Lying                          sometimes    everytime it suits me
# InternetUsage            few hours a day          few hours a day
# Gender                              male                   female
# LeftRightHanded             right handed             right handed
# Education               secondary school         secondary school
# OnlyChild                             no                       no
# VillageTown                         city                     city
# HouseFlats                block of flats           house/bungalow
#
#                                     1006                           1007  \
# Smoking                     never smoked                  tried smoking
# Alcohol                   social drinker                 social drinker
# Punctuality             i am often early        i am often running late
# Lying                          sometimes  only to avoid hurting someone
# InternetUsage    less than an hour a day                most of the day
# Gender                              male                         female
# LeftRightHanded              left handed                   right handed
# Education                 masters degree               secondary school
# OnlyChild                             no                            yes
# VillageTown                      village                           city
# HouseFlats                house/bungalow                 block of flats
#
#                                     1008                     1009
# Smoking                    tried smoking            tried smoking
# Alcohol                   social drinker           social drinker
# Punctuality      i am often running late  i am often running late
# Lying                          sometimes    everytime it suits me
# InternetUsage            most of the day          few hours a day
# Gender                            female                     male
# LeftRightHanded             right handed             right handed
# Education        college/bachelor degree         secondary school
# OnlyChild                             no                       no
# VillageTown                         city                  village
# HouseFlats                block of flats           house/bungalow
#
# [11 rows x 1005 columns]

# %%
categorical_cols = list(df.loc[:, categorical])

# %%
categorical_cols
# Out:
# ['Smoking',
#  'Alcohol',
#  'Punctuality',
#  'Lying',
#  'InternetUsage',
#  'Gender',
#  'LeftRightHanded',
#  'Education',
#  'OnlyChild',
#  'VillageTown',
#  'HouseFlats']

# %% [markdown]
# There are a lot of ordinal columns, which is better because we will not occur in a feature explosion using OHE, I think the ordinal values could be:
#
# * Punctuality
# * InternetUsage
# * Education
#
# Some other that only have True/False or Yes/No or in general 2 possible values can be encoded using the same attribute and an integer value (0 or 1), these features are:
#
# * Gender
# * LeftRightHanded
# * OnlyChild
# * VillageTown
# * HouseFlats
#
# The remaining categorical attributes are the ones that I think are the most important to predict empathy or that are not really ordinal and I would not want to introduce a bias by considering them as ordinal, these attributes are:
#
# * Smoking
# * Lying
# * Alcohol

# %%
print("Unique values of Smoking")
print(df.Smoking.unique())

print("\nUnique values of Lying")
print(df.Lying.unique())
# Out:
# Unique values of Smoking
# ['never smoked' 'tried smoking' 'former smoker' 'current smoker']
#
# Unique values of Lying
# ['never' 'sometimes' 'only to avoid hurting someone'
#  'everytime it suits me']

# %%
df.shape
# Out:
# (1005, 150)

# %%
def OHE_Smoking_N(value):
    return 1 if value=='never smoked' else 0

def OHE_Smoking_T(value):
    return 1 if value=='tried smoking' else 0

def OHE_Smoking_F(value):
    return 1 if value=='former smoker' else 0

def OHE_Smoking_C(value):
    return 1 if value=='current smoker' else 0

# %%
df['Smoking_Never'] = df.Smoking.apply(OHE_Smoking_N)
df['Smoking_Tried'] = df.Smoking.apply(OHE_Smoking_T)
df['Smoking_Former'] = df.Smoking.apply(OHE_Smoking_F)
df['Smoking_Current'] = df.Smoking.apply(OHE_Smoking_C)

# %%
def OHE_Lying_N(value):
    return 1 if value=='never' else 0

def OHE_Lying_S(value):
    return 1 if value=='sometimes' else 0

def OHE_Lying_O(value):
    return 1 if value=='only to avoid hurting someone' else 0

def OHE_Lying_E(value):
    return 1 if value=='everytime it suits me' else 0

# %%
df['Lying_Never'] = df.Lying.apply(OHE_Lying_N)
df['Lying_Sometimes'] = df.Lying.apply(OHE_Lying_S)
df['Lying_Only'] = df.Lying.apply(OHE_Lying_O)
df['Lying_Everytime'] = df.Lying.apply(OHE_Lying_E)

# %%
def OHE_Alcohol_D(value):
    return 1 if value=='drink a lot' else 0

def OHE_Alcohol_S(value):
    return 1 if value=='social drinker' else 0

def OHE_Alcohol_N(value):
    return 1 if value=='never' else 0

# %%
df['Alcohol_Drink'] = df.Alcohol.apply(OHE_Alcohol_D)
df['Alcohol_Social'] = df.Alcohol.apply(OHE_Alcohol_S)
df['Alcohol_Never'] = df.Alcohol.apply(OHE_Alcohol_N)

# %% [markdown]
# #### True False OHE

# %%
def OHE_Male(value):
    return 1 if value=='male' else 0

# %%
df['Male'] = df.Gender.apply(OHE_Male)

# %%
def OHE_Right(value):
    return 1 if value=='right handed' else 0

# %%
df['Right_Handed'] = df.LeftRightHanded.apply(OHE_Right)

# %%
def OHE_Only(value):
    return 1 if value=='yes' else 0

# %%
df['Only_Child'] = df.OnlyChild.apply(OHE_Only)

# %%
def OHE_City(value):
    return 1 if value=='city' else 0

# %%
df['City'] = df.VillageTown.apply(OHE_City)

# %%
def OHE_House(value):
    return 1 if value=='house/bungalow' else 0

# %%
df['House'] = df.HouseFlats.apply(OHE_House)

# %% [markdown]
# #### Ordinal

# %%
print("Unique values of Punctuality")
print(df.Punctuality.unique())
# Out:
# Unique values of Punctuality
# ['i am always on time' 'i am often early' 'i am often running late']

# %%
def OHE_Punctuality_Ordinal(value):
    if value=='i am always on time':
        return 1
    if value=='i am often early':
        return 2 
    if value=='i am often running late':
        return 0
    #should not arrive here
    return 0

# %%
df['Punctual'] = df.Punctuality.apply(OHE_Punctuality_Ordinal)

# %%
print("Unique values of InternetUsage")
print(df.InternetUsage.unique())
# Out:
# Unique values of InternetUsage
# ['few hours a day' 'most of the day' 'less than an hour a day'
#  'no time at all']

# %%
def OHE_InternetUsage_Ordinal(value):
    if value=='most of the day':
        return 3
    if value=='few hours a day':
        return 2 
    if value=='less than an hour a day':
        return 1
    if value=='no time at all':
        return 0
    #should not arrive here
    return 0

# %%
df['InternetUsage'] = df.InternetUsage.apply(OHE_InternetUsage_Ordinal)

# %%
print("Unique values of Education")
print(df.Education.unique())
# Out:
# Unique values of Education
# ['college/bachelor degree' 'secondary school' 'primary school'
#  'masters degree' 'doctorate degree' 'currently a primary school pupil']

# %%
def OHE_Education_Ordinal(value):
    if value=='doctorate degree':
        return 5
    if value=='masters degree':
        return 4 
    if value=='college/bachelor degree':
        return 3
    if value=='secondary school':
        return 2
    if value=='primary school':
        return 1
    if value=='currently a primary school pupil':
        return 0
    #should not arrive here
    return 0

# %%
df['Education'] = df.Education.apply(OHE_Education_Ordinal)

# %% [markdown]
# #### Deleting categorical columns that were encoded

# %%
encoded_columns = ['Smoking','Lying','Alcohol','Gender','LeftRightHanded','OnlyChild','VillageTown','HouseFlats','Punctuality']

# %%
df = df.drop(encoded_columns, axis=1)

# %%
df.shape
# Out:
# (1005, 158)

# %%
pd.options.display.max_columns = 158
pd.options.display.max_rows = 158

# %% [markdown]
# ### Exploring relevant features

# %%
all_columns =list(df)

# %%
# %matplotlib inline

# %%
df.shape[1]
# Out:
# 158

# %%
cov = {}
for col in all_columns:
    if col != 'Empathy':
        l = ['Empathy']
        l.append(col)
        cov[col] = df['Empathy'].corr(df[col])

# %%
import operator
sorted_cov = sorted(cov.items(), key=operator.itemgetter(1))

# %%
most_correlated = []
for item in sorted_cov[:5]:
    most_correlated.append(item[0])
for item in sorted_cov[-5:]:
    most_correlated.append(item[0])
most_correlated
# Out:
# ['Male',
#  'Weight',
#  'Cars',
#  'Fake',
#  'Height',
#  'Latino',
#  'Fantasy/Fairy tales',
#  'Children',
#  'Judgment calls',
#  'Life struggles']

# %% [markdown]
# ### Matrix correlation for the 10 features which are correlated (positive or negative) the most to Empathy

# %%
f, ax = plt.subplots(figsize=(15, 9))
cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(
    covariance,
    cmap=cmap,
    vmax=.3,
    center=0,
    square=True,
    annot=True,
    linewidths=.5,
    cbar_kws={"shrink": .5})

# %% [markdown]
# We can notice that there also redundant features such as weight and height, because they are very correlated to the gender. Intuitively, this is true, an average man weights more and is taller than an average woman. Some algorithms such as random forest, can deal with this type of redundancies pretty well by selecting a random subsample of features for every tree. I would not worry now about dealing with all the correlated features.

# %% [markdown]
# At this point the preprocessing should be done, I will save the dataset so I don't have to run all the cells again next time.

# %%
df.to_csv('./input/preprocessed_dataset', index=False)

# %% [markdown]
# #### PCA
# I tried PCA (PCAtest notebook) for dimensionality reduction by I did not apply it at the end, so I didn't include the code in this notebook that is gonna become pretty heavy

# %% [markdown]
# # Models

# %% [markdown]
# ## Reasoning about a model

# %% [markdown]
# The problem is a binary classification problem: Empathetic, Not empathetic. However, I can also try to exploit the fact that the dataset is given with the label "empathy" which can be a value between 0 and 5, 4 and 5 means empathetic, 1, 2 and 3 means not empathetic.
#
# Exploiting this fact I could use regressor models and use powerful algorithms such as random forests. Since we have a lot of features, the random choosing of features for each tree could be beneficial. Also, there are a lot of correlated predictors which are well handled by bagging but not by boosting methods.
#
# I will also try some good bagging algorithms like XGBoost, for this type of algorithms I would most likely have to apply PCA for highly correlated data to get orthogonal variables, or let an algorithm select a subset of relevant features and only use a subset of all features.

# %%
df = pd.read_csv('./input/preprocessed_dataset')

# %% [markdown]
# ## Baseline models
# before trying to go straight towards more powerful algorithms, let's see how some simple algorithms work to have an idea of how difficult the problem is and what is the baseline accuracy

# %% [markdown]
# ### Logistic Regression

# %% [markdown]
# ### Predicting multiclass and converting in 0-1 after

# %%
from sklearn.linear_model import LogisticRegression

# %%
pivot = int(0.8 * len(df))
predicting_features = list(df)
predicting_features.remove('Empathy')

x = np.array(df[predicting_features])
y = np.array(df['Empathy'])

x_test = x[pivot:]
x_train = x[:pivot]

y_test = y[pivot:]
y_train = y[:pivot]

print("Len validation:", len(x_test), "Len train:", len(x_train))
# Out:
# Len validation: 201 Len train: 804

# %%
LR = LogisticRegression()

LR.fit(x_train, y_train)
# score = model.score(x_test, y_test)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
y_hat = LR.predict(x_test)

# %%
from numpy import *

# %%
y_hat_train = LR.predict(x_train)

# %%
def transform_in_binary(empathy_level):
    return 0 if empathy_level < 4 else 1

# %%
bin_trans = vectorize(transform_in_binary)

# %%
y_hat_binary = bin_trans(y_hat)
y_test_binary = bin_trans(y_test)

# %%
y_hat_train_binary = bin_trans(y_hat_train)
y_train_binary = bin_trans(y_train)

# %%
print('accuracy on Test')
mean(y_hat_binary == y_test_binary)
# Out:
# accuracy on Test
# 0.6417910447761194

# %%
print('accuracy on Train')
mean(y_hat_train_binary == y_train_binary)
# Out:
# accuracy on Train
# 0.8407960199004975

# %% [markdown]
# The model is somewhat overfitting and the accuracy is not that great

# %% [markdown]
# ## Baseline model: Support Vector Machines

# %% [markdown]
# ### OVO SVM

# %%
from sklearn import svm

# %%
svm_ovo = svm.SVC(C=1.0, decision_function_shape='ovo')
svm_ovo.fit(x_train, y_train) 

# dec = clf.decision_function([[1]])
# dec.shape[1] # 4 classes: 4*3/2 = 6

# clf.decision_function_shape = "ovr"
# dec = clf.decision_function([[1]])
# dec.shape[1] # 4 classes
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovo', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
y_hat = svm_ovo.predict(x_test)

# %%
y_hat_binary = bin_trans(y_hat)
y_test_binary = bin_trans(y_test)

# %%
print('accuracy:')
mean(y_hat_binary == y_test_binary)
# Out:
# accuracy:
# 0.6019900497512438

# %%
y_hat_train = svm_ovo.predict(x_train)

# %%
print('accuracy on training')
mean(y_hat_train == y_train)
# Out:
# accuracy on training
# 0.9664179104477612

# %% [markdown]
# In this case the model is overfitting a lot more, and the accuracy is pretty bad

# %% [markdown]
# ### Linear SVM binary classification

# %%
svm_linear = svm.SVC()
svm_linear.fit(x_train, y_train_binary)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
y_hat_binary = svm_linear.predict(x_test)

# %%
mean(y_hat_binary == y_test_binary)
# Out:
# 0.6417910447761194

# %% [markdown]
# This is a little better than OVO multiclass SVM

# %% [markdown]
# ## Majority voting classifier

# %%
mean(concatenate((y_train_binary,y_test_binary), axis=None))
# Out:
# 0.6616915422885572

# %% [markdown]
# The expected accuracy of a majority voting classifier is around 66%, this means the baselines are doing pretty bad and the problem is somewhat complex.
#
# Complex model -> complex algorithms needed, let's try to see how random forest perform

# %% [markdown]
# ## Random Forest regressor
# I will first try to use regression with random forest leaving the Empathy on a scale from 1 to 5 and then convert the results in 0-1

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor

# %%
len(selected_features)
# Out:
# 157

# %%
#selected_features

# %%
selected_features = predicting_features

# %%
x = np.array(df[selected_features])
y = np.array(df['Empathy'])

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=23)
print('df.shape    ', df.shape)
print('x_train.shape ', x_train.shape)
print('x_test.shape  ', x_test.shape)
print('y_train.shape  ', y_train.shape)
print('y_test.shape  ', y_test.shape)
# Out:
# df.shape     (1005, 158)
# x_train.shape  (804, 157)
# x_test.shape   (201, 157)
# y_train.shape   (804,)
# y_test.shape   (201,)

# %%
RFR = RandomForestRegressor(n_estimators=300, n_jobs=-1, verbose=0)

# %%
RFR.fit(x_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=300, n_jobs=-1,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %% [markdown]
# #### Let's plot the features by their importance found by the algorithm

# %%
idx = RFR.feature_importances_.argsort()[::-1]

# %%
ax = sns.barplot(x=df[selected_features].columns[idx], y=RFR.feature_importances_[idx])
_ = plt.setp(ax.get_xticklabels(), rotation=-90)

# %% [markdown]
# We could also do a feature selection here, based on the importances found by the random forest

# %%
#idx

# %%
#a = np.array(selected_features)
#selected = list(idx[:100])
#selected_features = list(a[selected])

# %%
#selected_features

# %%
# selected_features[151]

# %%
#ax = sns.barplot(x=df[selected_features].columns[idx[:12]], y=RFR.feature_importances_[idx[:12]])
#_ = plt.setp(ax.get_xticklabels(), rotation=-90)

# %%
y_hat = RFR.predict(x_test)

# %%
mean(y_hat)
# Out:
# 3.804776119402985

# %%
mean(y_test)
# Out:
# 3.711442786069652

# %%
def transform_contininous_in_binary(empathy_level):
    return 0 if empathy_level < 3.5 else 1
cont_bin_trans = vectorize(transform_contininous_in_binary)
y_hat_binary = cont_bin_trans(y_hat)
y_test_binary = cont_bin_trans(y_test)

# %%
mean(y_hat_binary == y_test_binary)
# Out:
# 0.7064676616915423

# %%
y_hat_train = RFR.predict(x_train)
y_hat_train_binary = cont_bin_trans(y_hat_train)
y_train_binary = cont_bin_trans(y_train)

# %%
mean(y_hat_train_binary == y_train_binary)
# Out:
# 0.9950248756218906

# %% [markdown]
# Despite its ability to limit overfitting, even random forest without tuning the hyperparameters overfit, I think that this means that the dataset is too small, a significant overfitting will almost always occur. The model is doing better than the baselines by at least 4%, so this is a good direction

# %% [markdown]
# ## Random forest binary classifier
# I will now try to do a 20-fold crossvalidation with a binary classifier (0-1)

# %%
def encode_emp(value):
    return 0 if value<4 else 1

# %%
df['Empathy'] = df.Empathy.apply(encode_emp)

# %%
from sklearn.model_selection import KFold
from sklearn.ensemble import RandomForestClassifier
kf = KFold(n_splits=20)
x = np.array(df[new_feat])
y = np.array(df['Empathy'])
kf.get_n_splits(x)

accuracy = []

for train_index, test_index in kf.split(x):
    x_train, x_test = x[train_index], x[test_index]
    y_train, y_test = y[train_index], y[test_index]
    RFR = RandomForestClassifier(n_estimators=50, max_depth= 15, max_features = 10, n_jobs=-1, verbose=0)
    
    RFR.fit(x_train, y_train)
    y_hat = RFR.predict(x_test)
    accuracy.append(mean(y_hat == y_test))

print(mean(accuracy))
#0.7215098039215686
# Out:
# 0.7124901960784314

# %% [markdown]
# Since this is a crossvalidation, this is a more realistic result, it's not bad

# %% [markdown]
# # Error detection and correction
# I will now try to understand where the predictor is doing bad, if there are some examples that are more prone to errors, for this task I will perform a leave-one-out crossvalidation,, so for each example I will train on the whole dataset minus that example and test on that, this is only possible since the dataset is really small, otherwise it would be computationally hard

# %% [markdown]
# ## LOO CV Random Forest binary classifier

# %%
df = pd.read_csv('./input/preprocessed_dataset')

# %%
from sklearn.model_selection import LeaveOneOut
loo = LeaveOneOut()
loo.get_n_splits(x)
# kf = KFold(n_splits=20)
x = np.array(df[selected_features])
y = np.array(df['Empathy'])
# kf.get_n_splits(x)

def transform_contininous_in_binary(empathy_level):
    return 0 if empathy_level < 3.5 else 1
cont_bin_trans = vectorize(transform_contininous_in_binary)

accuracy = []

for train_index, test_index in loo.split(x):
#     print("TRAIN:", train_index, "TEST:", test_index)
    x_train, x_test = x[train_index], x[test_index]
    y_train, y_test = y[train_index], y[test_index]
#     print(y_train)
#     print(y_test)
    RFR = RandomForestRegressor(n_estimators=100, max_depth= 6, n_jobs=-1, verbose=0)
    
    RFR.fit(x_train, y_train)
    y_hat = RFR.predict(x_test)
    y_hat_binary = cont_bin_trans(y_hat)
#     print(y_hat)
#     print(y_hat_binary)
    y_test_binary = cont_bin_trans(y_test)
#     print(y_test)
#     print(y_test_binary)
#     print(mean(y_hat_binary == y_test_binary))
    accuracy.append(mean(y_hat_binary == y_test_binary))

print(mean(accuracy))
#0.7215098039215686
# Out:
# 0.7194029850746269

# %% [markdown]
# ### Wrong predicted examples
# From the accuracy I can find out the missclassified examples, take all the missclassified examples and look at some statistics to find useful patterns

# %%
accuracy

# %%
one = array(accuracy)

# %%
one
# Out:
# array([0., 0., 1., ..., 1., 1., 1.])

# %%
wrong_predicted = df[one == 0]

# %% [markdown]
# This are the statistics for the entire dataset for comparison

# %%
df.describe()
# Out:
#              Music  Slow songs or fast songs        Dance         Folk  \
# count  1005.000000               1005.000000  1005.000000  1005.000000
# mean      4.736318                  3.330348     3.112438     2.288557
# std       0.659835                  0.831600     1.170817     1.137166
# min       1.000000                  1.000000     1.000000     1.000000
# 25%       5.000000                  3.000000     2.000000     1.000000
# 50%       5.000000                  3.000000     3.000000     2.000000
# 75%       5.000000                  4.000000     4.000000     3.000000
# max       5.000000                  5.000000     5.000000     5.000000
#
#            Country  Classical music      Musical          Pop         Rock  \
# count  1005.000000      1005.000000  1005.000000  1005.000000  1005.000000
# mean      2.123383         2.956219     2.763184     3.470647     3.773134
# std       1.075210         1.244939     1.261457     1.159743     1.183500
# min       1.000000         1.000000     1.000000     1.000000     1.000000
# 25%       1.000000         2.000000     2.000000     3.000000     3.000000
# 50%       2.000000         3.000000     3.000000     4.000000     4.000000
# 75%       3.000000         4.000000     4.000000     4.000000     5.000000
# max       5.000000         5.000000     5.000000     5.000000     5.000000
#
#        Metal or Hardrock         Punk  Hiphop, Rap  Reggae, Ska  Swing, Jazz  \
# count        1005.000000  1005.000000  1005.000000  1005.000000  1005.000000
# mean            2.358209     2.446766     2.915423     2.770149     2.757214
# std             1.375310     1.303688     1.374139     1.210802     1.253187
# min             1.000000     1.000000     1.000000     1.000000     1.000000
# 25%             1.000000     1.000000     2.000000     2.000000     2.000000
# 50%             2.000000     2.000000     3.000000     3.000000     3.000000
# 75%             3.000000     3.000000     4.000000     4.000000     4.000000
# max             5.000000     5.000000     5.000000     5.000000     5.000000
#
#        Rock n roll  Alternative       Latino  Techno, Trance        Opera  \
# count  1005.000000  1005.000000  1005.000000     1005.000000  1005.000000
# mean      3.140299     2.830846     2.834826        2.333333     2.141294
# std       1.231726     1.341657     1.324223        1.325258     1.185880
# min       1.000000     1.000000     1.000000        1.000000     1.000000
# 25%       2.000000     2.000000     2.000000        1.000000     1.000000
# 50%       3.000000     3.000000     3.000000        2.000000     2.000000
# 75%       4.000000     4.000000     4.000000        3.000000     3.000000
# max       5.000000     5.000000     5.000000        5.000000     5.000000
#
#             Movies       Horror     Thriller       Comedy     Romantic  \
# count  1005.000000  1005.000000  1005.000000  1005.000000  1005.000000
# mean      4.615920     2.793035     3.384080     4.497512     3.488557
# std       0.694131     1.412435     1.197501     0.777705     1.209655
# min       1.000000     1.000000     1.000000     1.000000     1.000000
# 25%
# min     15.000000  153.000000   43.000000            0.000000    0.000000
# 25%     19.000000  168.000000   57.250000            1.000000    2.000000
# 50%     20.000000  173.000000   65.000000            1.000000    2.000000
# 75%     22.000000  180.000000   76.000000            2.000000    3.000000
# max     30.000000  200.000000  150.000000            5.000000    5.000000
#
#        Smoking_Never  Smoking_Tried  Smoking_Former  Smoking_Current  \
# count     282.000000     282.000000      282.000000       282.000000
# mean        0.230496       0.414894        0.166667         0.187943
# std         0.421899       0.493580        0.373341         0.391361
# min         0.000000       0.000000        0.000000         0.000000
# 25%         0.000000       0.000000        0.000000         0.000000
# 50%         0.000000       0.000000        0.000000         0.000000
# 75%         0.000000       1.000000        0.000000         0.000000
# max         1.000000       1.000000        1.000000         1.000000
#
#        Lying_Never  Lying_Sometimes  Lying_Only  Lying_Everytime  \
# count   282.000000       282.000000  282.000000       282.000000
# mean      0.063830         0.539007    0.255319         0.141844
# std       0.244884         0.499362    0.436816         0.349510
# min       0.000000         0.000000    0.000000         0.000000
# 25%       0.000000         0.000000    0.000000         0.000000
# 50%       0.000000         1.000000    0.000000         0.000000
# 75%       0.000000         1.000000    1.000000         0.000000
# max       1.000000         1.000000    1.000000         1.000000
#
#        Alcohol_Drink  Alcohol_Social  Alcohol_Never        Male  Right_Handed  \
# count     282.000000      282.000000     282.000000  282.000000    282.000000
# mean        0.234043        0.624113       0.141844    0.460993      0.921986
# std         0.424152        0.485212       0.349510    0.499362      0.268671
# min         0.000000        0.000000       0.000000    0.000000      0.000000
# 25%         0.000000        0.000000       0.000000    0.000000      1.000000
# 50%         0.000000        1.000000       0.000000    0.000000      1.000000
# 75%         0.000000        1.000000       0.000000    1.000000      1.000000
# max         1.000000        1.000000       1.000000    1.000000      1.000000
#
#        Only_Child       City       House    Punctual
# count  282.000000  282.00000  282.000000  282.000000
# mean     0.294326    0.70922    0.425532    1.078014
# std      0.456549    0.45493    0.495302    0.783013
# min      0.000000    0.00000    0.000000    0.000000
# 25%      0.000000    0.00000    0.000000    0.000000
# 50%      0.000000    1.00000    0.000000    1.000000
# 75%      1.000000    1.00000    1.000000    2.000000
# max      1.000000    1.00000    1.000000    2.000000

# %% [markdown]
# ## Error Fixing
# I especially looked at the mean. Most of the means between same features in the 2 different datasets are similar, at most 0.2 of difference. The only one which is really different is the class label Empathy. For this feature, in fact, the entire dataset has an average of 3.85, while the missclassified examples have an average Empathy of 2.98.
#
# Moreover, the 75% percentile is 3 for the missclassified examples. This means that at least 75% of these examples will fall in the category on *Not very empathetic*, therefore, the problem in the prediction is mainly the inability of understanding when to predict 0.
#
# I thought at how to improve this, and I think I will create a custom ensemble by using a different model and do the same prediction, if either one of them predicts 0, I will assign 0 to that (logic AND of the predictions)

# %% [markdown]
# ## Train/dev/test split
# With this small dataset, it's really unconvenient to use a big part of the dataset to train hyperparameters (dev set), so I will only take about 5% of the dataset to use it as dev set.
#
# As for train and test set, to have valid and reliable results and not just lucky splits, I will use crossvalidation on the remaining 95% on the dataset

# %%
df = pd.read_csv('./input/preprocessed_dataset')
def encode_emp(value):
    return 0 if value<4 else 1
df['Empathy'] = df.Empathy.apply(encode_emp)

# %%
dev_i = 150
dev_f = 200
msk = arange(1005) < dev_f
m = arange(1005) >dev_i
msk = msk & m
train = df[~msk]
dev = df[msk]

# %% [markdown]
# ## PARAMETER TUNING

# %%
from sklearn.model_selection import validation_curve
from sklearn.ensemble import RandomForestClassifier

# %%
params = range(10, 101, 10)  #50,201,50

# %%
scores, tst_scr = validation_curve(RandomForestClassifier(max_depth= 20), dev[selected_features],\
                                       dev['Empathy'], 'n_estimators', params, \
                                       cv=5,n_jobs=-1, verbose=1)
# Out:
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:    0.5s finished

# %%
scores_mean = scores.mean(axis=1)
scores_std = scores.std(axis=1)
tst_scr_mean = tst_scr.mean(axis=1)
tst_scr_std = tst_scr.std(axis=1)
plt.plot(params, tst_scr_mean)
plt.fill_between(params, tst_scr_mean + tst_scr_std, tst_scr_mean - tst_scr_std, alpha=0.3)
plt.plot(params, scores_mean)
plt.fill_between(params, scores_mean + scores_std, scores_mean - scores_std, alpha=0.3)

# %%
params = range(1, 16, 1)  #50,201,50

# %%
scores, tst_scr = validation_curve(RandomForestClassifier(), dev[selected_features],\
                                       dev['Empathy'], 'max_depth', params, \
                                       cv=10,n_jobs=-1, verbose=1)
# Out:
# [Parallel(n_jobs=-1)]: Done 150 out of 150 | elapsed:    0.4s finished

# %%
scores_mean = scores.mean(axis=1)
scores_std = scores.std(axis=1)
tst_scr_mean = tst_scr.mean(axis=1)
tst_scr_std = tst_scr.std(axis=1)
plt.plot(params, tst_scr_mean)
plt.fill_between(params, tst_scr_mean + tst_scr_std, tst_scr_mean - tst_scr_std, alpha=0.3)
plt.plot(params, scores_mean)
plt.fill_between(params, scores_mean + scores_std, scores_mean - scores_std, alpha=0.3)

# %%
params = range(6, 14, 1)  #50,201,50

# %%
scores, tst_scr = validation_curve(RandomForestClassifier(n_estimators= 100), dev[selected_features],\
                                       dev['Empathy'], 'max_features', params, \
                                       cv=10,n_jobs=-1, verbose=1)
# Out:
# [Parallel(n_jobs=-1)]: Done  80 out of  80 | elapsed:    1.2s finished

# %%
scores_mean = scores.mean(axis=1)
scores_std = scores.std(axis=1)
tst_scr_mean = tst_scr.mean(axis=1)
tst_scr_std = tst_scr.std(axis=1)
plt.plot(params, tst_scr_mean)
plt.fill_between(params, tst_scr_mean + tst_scr_std, tst_scr_mean - tst_scr_std, alpha=0.3)
plt.plot(params, scores_mean)
plt.fill_between(params, scores_mean + scores_std, scores_mean - scores_std, alpha=0.3)

# %% [markdown]
# # XGBoost
# Another known powerful algorithm that could be integrated in the ensemble that I described in the paragraph *Error Fixing* is XGBoost. I decided that it would be a bagging algorithm since it uses a different approach than bagging and the combination of the two could lead to something interesting.
#
# I will start with a feature selection since Boosting does not work well with a lot of features, especially if they are correlated

# %%
# !pip install xgboost

# %% [markdown]
# ## Feature selection for XGB

# %%
from sklearn.feature_selection import SelectKBest, f_classif, f_regression

# Perform feature selection
selector = SelectKBest(f_regression, k=50)
selector.fit(df[selected_features], df['Empathy'])

# Get the raw p-values for each feature, and transform from p-values into scores
scores = -np.log10(selector.pvalues_)

# Plot the scores for each feature 
plt.bar(range(len(selected_features)), scores)
plt.xticks(range(len(selected_features)), selected_features, rotation='vertical')
plt.title('K Best Features')
plt.show()

# %%
sc = list(zip(selected_features,scores))
sc.sort(key=lambda tup: tup[1])

# %%
print('The most important 20 features')
sc.sort(key=lambda tup: tup[1])  # sorts in place
a = sc[137:]
new_feat = [x for (x,y) in a]
new_feat.reverse()
new_feat
# Out:
# The most important 20 features
# ['Judgment calls',
#  'Male',
#  'Life struggles',
#  'Psychology',
#  'Compassion to animals',
#  'Children',
#  'Latino',
#  'Fantasy/Fairy tales',
#  'Weight',
#  'Friends versus money',
#  'Cars',
#  'Theatre',
#  'Fake',
#  'PC',
#  'Reading',
#  'Spending on gadgets',
#  'Loss of interest',
#  'Borrowed stuff',
#  'Height',
#  'Foreign languages']

# %%
import xgboost as xgb

# %% [markdown]
# ### Params tuning XGBoost
# The tuning of the parameters of XGBoost is kind of complex, I will use the RandomizedSearchCV but I don't expect to have great results on such a small dev set

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
from xgboost.sklearn import XGBRegressor # wrapper
# XGB with sklearn wrapper
# the same parameters as for xgboost model
params_sk = {
            "objective": "binary:hinge",
            'max_depth': 8, 
           'n_estimators': 100, # the same as num_rounds in xgboost
           'subsample': 1.0, 
           'colsample_bytree': 0.3,  
           'seed': 23}     

skrg = XGBRegressor(**params_sk)

skrg.fit(dev[new_feat],dev["Empathy"])
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=0.3, gamma=0, importance_type='gain',
#        learning_rate=0.1, max_delta_step=0, max_depth=8,
#        min_child_weight=1, missing=None, n_estimators=100, n_jobs=1,
#        nthread=None, objective='binary:hinge', random_state=0, reg_alpha=0,
#        reg_lambda=1, scale_pos_weight=1, seed=23, silent=True,
#        subsample=1.0)

# %%
import scipy.stats as st

params_grid = {  
   'learning_rate': st.uniform(0.01, 0.5),
   'max_depth': list(range(10, 30, 2)),
   'gamma': st.uniform(0, 15),
   'reg_alpha': st.uniform(1, 15)}

search_sk = RandomizedSearchCV(skrg, params_grid, cv = 5, verbose=1) # 3 fold cross validation
search_sk.fit(dev[new_feat], dev["Empathy"])

# best parameters
print(search_sk.best_params_); print(search_sk.best_score_)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# {'gamma': 1.6676002444557636, 'learning_rate': 0.2471511128208139, 'max_depth': 24, 'reg_alpha': 8.550606464293036}
# -0.44169096209912556
# [Parallel(n_jobs=1)]: Done  50 out of  50 | elapsed:    0.4s finished

# %% [markdown]
# I want to include a plot of the most important features for XGboost when I trained it on all the features and got a pretty bad performance (too many correkated features), just to make a comparison with the most important features selected by Random Forest

# %%
# # Feature importance XGB for all features 
from xgboost import plot_importance
plot_importance(gbm, importance_type="gain", max_num_features=50)
plt.title("XGBoost Feature Gain")
plt.show()

# %% [markdown]
# # Final model: 10-fold CV ensemble XGB and RF binary classifiers
# This final model is built by using two binary classifier models: Random Forest and XGboost, the final prediction happens by using a custom ensemble in which if either one of them predicts 0, I will assign 0 to that (logic AND of the predictions), this choice was done because of the considerations done in the paragraphs *Error detection and correction* and *Error Fixing*

# %%
df = pd.read_csv('./input/preprocessed_dataset')
def encode_emp(value):
    return 0 if value<4 else 1
df['Empathy'] = df.Empathy.apply(encode_emp)

# %%
train.shape
# Out:
# (956, 158)

# %%
from sklearn.model_selection import KFold
import xgboost as xgb
kf = KFold(n_splits=10)
x = np.array(train[selected_features])
x_xgb = np.array(train[new_feat])
y = np.array(train['Empathy'])
kf.get_n_splits(x)

params = {"objective": "binary:hinge",
          #"num_class": 2,
          "eta": 0.2,   #0.17
          "max_depth": 24,
          "subsample": 0.5,  #0.8
          "colsample_bytree": 0.3, #0.3 #0.2
          "silent": 1,
          "nthread":-1,
          #added as a test
          #"eval_metric": "rmse",
          "seed": 24,
          #"reg_alpha": 2  #4
          "gamma": 1,  #added as a test
          "reg_alpha": 12
          }

#reg_alpha 
#reg_lambda
num_trees = 400 #400

accuracy = []
accuracy_rf = []
accuracy_xgb = []

for train_index, test_index in kf.split(x):
#     print("TRAIN:", train_index, "TEST:", test_index)
    x_train, x_test = x[train_index], x[test_index]
    x_xgb_train, x_xgb_test = x_xgb[train_index], x_xgb[test_index]
    y_train, y_test = y[train_index], y[test_index]
    
    dtrain = xgb.DMatrix(x_xgb_train, y_train)
    dvalid = xgb.DMatrix(x_xgb_test, y_test)
#     print(y_train)
#     print(y_test)
    watchlist = [(dvalid, 'test'), (dtrain, 'train')]
    gbm = xgb.train(params, dtrain, num_trees, evals=watchlist, early_stopping_rounds=50, verbose_eval=False)
    #RF
    RFR = RandomForestClassifier(n_estimators=100, max_depth= 15, max_features = 10, n_jobs=-1, verbose=0)
    RFR.fit(x_train, y_train)
    
    y_hat_rf = RFR.predict(x_test)
    y_hat = gbm.predict(xgb.DMatrix(x_xgb_test))
    
#     print('y_hat rf')
#     print(y_hat_rf[:20])
#     print('y_hat xgb')
#     print(y_hat[:20])
#     print('y_true')
#     print(y_test[:20])
    

    y_hat_ensemble = y_hat_rf*y_hat

#     print('ensemble')
#     print(y_hat_ensemble[:20])
    
    accuracy.append(mean(y_hat_ensemble == y_test))
    accuracy_rf.append(mean(y_hat_rf == y_test))
    accuracy_xgb.append(mean(y_hat == y_test))


print(mean(accuracy))
print(mean(accuracy_rf))
print(mean(accuracy_xgb))

#0.7215098039215686
# Out:
# 0.7300548245614035
# 0.7184210526315791
# 0.7279276315789474

# %% [markdown]
# ## Final considerations
# As we can see, the crossvalidated final model accuracy is 73%, by training and testing only on 95% of the dataset (5% was used to tune hyperparameters). I also printed the single accuracy that the single models would have without their ensemble, and it's 71.8% for RF and 72.7% for XGB.
#
# The final ensemble result is better than the 2 single models, and better than the first Random Forest model that I tried. Boosting definitely brought improvements, and it was only working on 20 features out of the 157 processed initial ones. This demonstrates that almost all of the features are actually useless to predict Empathy.
#
# Also, my conclusion is that this dataset was not made to predict the Empathy. It is a difficult task to predict Empathy since the accuracy is not that great given a 66% baseline, and the initial task of finding people that are very empathetic is not easily achievable in this way. Too many false positives are found given this dataset.
#
# The reason why this happens is also probably because the dataset comes from a survey, people wrote how they think they are empathetic from 1 to 5 and this is not necessary true, it's just what they think of themselves or what they want to believe. So really, what we are predicting here is how much people think they are empathetic, given some facts (age, children, gender..) and some other tastes.
